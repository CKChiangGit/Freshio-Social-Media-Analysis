# %% [markdown]
# # Analysing Top 10
# - Content creator are categorised as those with at least 4,000 to 5,000 followers and have a sort of content creation biz model.

# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv("Pagerank_Top_100.csv")
df
# Out:
#                                        profileUrl             profileName  \
# 0               https://instagram.com/house_no_6/              house_no_6
# 1                   https://instagram.com/the_xw/                  the_xw
# 2             https://instagram.com/mr.ninja_kit/            mr.ninja_kit
# 3             https://instagram.com/thejonnieboy/            thejonnieboy
# 4            https://instagram.com/bambiepen5678/           bambiepen5678
# ..                                            ...                     ...
# 94      https://instagram.com/milkteaconnoisseur/      milkteaconnoisseur
# 95              https://instagram.com/pongxinzhi/              pongxinzhi
# 96            https://instagram.com/phua.jieying/            phua.jieying
# 97               https://instagram.com/chewkarin/               chewkarin
# 98  https://instagram.com/celine_doterrawellness/  celine_doterrawellness
#
#                                              fullName  followersCount  \
# ...

# %%
df[df['profileName'] == 'the_xw']
# Out:
#                       profileUrl profileName fullName  followersCount  \
# 1  https://instagram.com/the_xw/      the_xw       XW           20003
#
#    followingCount  isBusinessAccount  joinedRecently          Type Category  \
# 1            6363              False           False  Photographer     Food
#
#    Rank_Count  Rank  isVerified  postsCount  \
# 1          98     2       False      5866.0
#
#                              website              publicEmail  \
# 1  http://jiaksimipng.wordpress.com/  jiaksimipng@outlook.com
#
#   businessCategory  businessZipCode
# 1              NaN              NaN

# %% [markdown]
# ## Analytics

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.histplot(df['followersCount'], bins=30, kde=True)
plt.title('Distribution of Followers Count')
plt.show()

# %% [markdown]
# ### By Type

# %%
type_counts = df['Type'].value_counts()

plt.figure(figsize=(12, 6))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(type_counts)))
plt.title('Distribution of Account Types')
plt.show()

# %%
# Get the value counts of each type from the top 10 rows
type_counts_top10 = df_top10['Type'].value_counts()

plt.figure(figsize=(12, 6))
plt.pie(type_counts_top10, labels=type_counts_top10.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(type_counts_top10)))
plt.title('Distribution of Account Types for Top 10')
plt.show()

# %%
# Get the value counts of each type from rows 11 to 100
type_counts_11to100 = df_11to100['Type'].value_counts()

plt.figure(figsize=(12, 6))
plt.pie(type_counts_11to100, labels=type_counts_11to100.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(type_counts_11to100)))
plt.title('Distribution of Account Types for Rows 11 to 100')
plt.show()

# %% [markdown]
# ### By Categories
# - Filtered by Type==Personal Blog

# %%
filtered_df = df[df['Type'] == 'Personal blog']
category_counts = filtered_df['Category'].value_counts()

plt.figure(figsize=(26, 18))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(category_counts)))
plt.title('Distribution of Account Categories (Personal Blogs)')
plt.show()

# %%
filtered_df = df[:10]
category_counts = filtered_df['Category'].value_counts()

plt.figure(figsize=(12, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(category_counts)))
plt.title('Distribution of Account Categories Top 10')
plt.show()

# %%
filtered_df = df[11:]
category_counts = filtered_df['Category'].value_counts()

plt.figure(figsize=(26, 18))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel", len(category_counts)))
plt.title('Distribution of Account Categories 11 to 99')
plt.show()
